# %%
import numpy as np
ary = [1,2,3,4,5]

# %%
min(ary)
# Out:
# 1

# %%
np.nanmin(ary)
# Out:
# C:\Users\jhpark\AppData\Local\Temp\ipykernel_21268\1452227728.py:1: RuntimeWarning: All-NaN axis encountered
#   np.nanmin(ary)
# nan
